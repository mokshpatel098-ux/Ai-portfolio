# %% [markdown]
# <a href="https://colab.research.google.com/github/mokshpatel098-ux/Ai-portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
numbers = np.array([1,2,3,4,5])

# %%
print(numbers)
# Out:
# [1 2 3 4 5]

# %%
marks = [56,67,90,76,80]
print(marks)
# Out:
# [56, 67, 90, 76, 80]

# %% [markdown]
# List versus Arrays
# 1. Lists are flexible, easy to use, but slower for calculation
# 2. Arrays are faster, better for calculations, and used in machine learning and data scinence

# %%
cat1 = [23,45,24,50]
cat2 = [45,50,30,39]
print(cat1+cat2)
# Out:
# [23, 45, 24, 50, 45, 50, 30, 39]

# %%
cat1 = np.array([23,45,24,50])
cat2 = np.array([45,50,30,33])
print(cat1+cat2)
# Out:
# [68 95 54 83]
